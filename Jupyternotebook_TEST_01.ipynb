# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyiast

# %%
xx = np.linspace(-50,100)

# %%
yy = 2*xx**2

# %%
plt.plot(xx,yy, '--',linewidth= 3)
plt.show()

# %% [markdown]
# # Markdown
# Is there any way to see all the section names
